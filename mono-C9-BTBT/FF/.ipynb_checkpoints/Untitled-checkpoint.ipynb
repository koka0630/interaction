# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import shutil as sh
import math
import time
import seaborn as sns

# %%
normal_data = np.random.randn(10, 12)
test_map=sns.heatmap(normal_data,center=0)

# %%
df_FF=pd.read_csv('C:\\Users\\youmo\\OSC\\interaction\\mono-C9-BTBT\\FF\\FF_phi1phi2.csv')
FF_map=df_FF.pivot("phi2", "phi1", "FF")

# %%
sns.heatmap(FF_map,vmax=0.0,cmap="Blues_r")
